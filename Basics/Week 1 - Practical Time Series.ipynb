# %% [markdown]
# # Simple Visualisations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = [91, 49, 76, 112, 97, 47, 70, 100, 8, 112, 95, 90, 78, 62, 56, 94, 65, 58, 109, 70, 109, 91, 71, 76, 68, 62, 134, 57, 83, 66]

# %% [markdown]
# ### Histograms & Density Distrubutions

# %%
# matplot histogram
plt.hist(data, color= 'green', edgecolor='black', density=True,)
plt.title('Histogram practice')
plt.xlabel('My data points')
plt.ylabel('density')
# Out:
# Text(0, 0.5, 'density')

# %%
# seaborn histogram
sns.distplot(data, hist=True, kde=False, color='blue', hist_kws={'edgecolor':'black'})
plt.title('Histogram practice')
plt.xlabel('My data points')
plt.ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')

# %%
# Density Plot
sns.distplot(data, hist=True, kde=True,
             bins=int(10),
             color='darkblue', hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})


plt.title('Density Distribution Imposed on Histogram')
plt.xlabel('my data points')
plt.ylabel
# Out:
# <function matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, **kwargs)>

# %% [markdown]
# ### Scatter Plots for bivariate data

# %%
#generate randomw data
import random
random.seed(2016)

Test_1_scores = []

for i in range(50):
    
    random_num = round(random.normalvariate(78, 10))
    Test_1_scores.append(random_num)

Test_2_scores = []
random.seed(2016)
for i in range(50):
    random_num = round(random.normalvariate(70, 14))
    Test_2_scores.append(random_num)
    
print(Test_1_scores)
# Out:
# [85, 65, 74, 78, 74, 72, 68, 82, 81, 91, 79, 70, 63, 88, 83, 74, 63, 68, 70, 81, 101, 85, 69, 78, 60, 69, 71, 65, 90, 91, 60, 62, 82, 74, 66, 97, 83, 82, 66, 64, 68, 86, 99, 84, 93, 76, 66, 92, 64, 81]

# %%
Test_1_scores = pd.series(Test_1_scores)
Test_2_scores = pd.series(Test_2_scores)
print(Test_2_scores)
print(Test_1_scores)

# %%
#matplot scatter
plt.scatter(Test_1_scores, Test_2_scores)

# %%
sns.scatterplot(Test_1_scores, Test_2_scores)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-7c5a8a3de893> in <module>
# ----> 1 sns.scatterplot(Test_1_scores, Test_2_scores)
#
# /opt/conda/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1400         x_bins=x_bins, y_bins=y_bins,
#    1401         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1402         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1403     )
#    1404
#
# ...
